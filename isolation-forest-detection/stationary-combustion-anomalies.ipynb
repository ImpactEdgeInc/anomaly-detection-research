# %% [markdown]
# # Detecting Anomalies In Stationary Combustion Data Through Isolated Forests
#
# ## Package Importing

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.ensemble import IsolationForest

# %% [markdown]
# ## Database Importing

# %%
import dotenv
import os
import psycopg2

dotenv.load_dotenv(dotenv_path='database.env')

# --- Configuration ---
DB_NAME = os.environ['DB_NAME']
DB_USER = os.environ['DB_USER']
DB_PASS = os.environ['DB_PASS']
HOST = os.environ['HOST']
PORT = os.environ['PORT']

# 2. Database Connection and Setup
conn = psycopg2.connect(
    dbname=DB_NAME, user=DB_USER, password=DB_PASS, host=HOST, port=PORT
)
conn.autocommit = True
cur = conn.cursor()

cur.execute('SELECT "facilityId","co2e","fuelHint","createdAt","ch4","n2o","ef","co2" FROM stationary_combustion_activity')

df = pd.DataFrame(cur.fetchall(), columns = ["facilityId","co2e","fuelHint","createdAt","ch4","n2o","ef","co2"])
print(df)
# Out:
#                                 facilityId          co2e  \
# 0     68f4851d-4959-49b6-96a1-63d80c816ed3      0.000000
# 1     bf2278d8-0d33-4e28-a55e-ad3c1537af7e      0.000054
# 2     4f4bf05a-0a52-48db-b66d-3b3da6b23619      0.000054
# 3     4f4bf05a-0a52-48db-b66d-3b3da6b23619      0.004033
# 4     4f4bf05a-0a52-48db-b66d-3b3da6b23619      0.010790
# ...                                    ...           ...
# 6160  beae4852-c882-4706-8dd9-f8ce4dc11989      0.222116
# 6161  d0f9256f-17f4-4b7e-abc7-2eeeba8d59c0      0.053958
# 6162  d0f9256f-17f4-4b7e-abc7-2eeeba8d59c0   9049.547300
# 6163  e0bd2a9c-69d4-403e-beed-3b9a6b08b382  12163.778891
# 6164  e0bd2a9c-69d4-403e-beed-3b9a6b08b382   6588.125943
#
#                            fuelHint                         createdAt  \
# 0                            Bamboo  2025-01-05 21:53:26.836000-08:00
# 1                       Natural Gas  2025-01-20 00:33:24.881000-08:00
# 2                       Natural Gas  2025-01-20 02:59:01.888000-08:00
# 3                       Natural Gas  2025-01-20 02:59:02.308000-08:00
# 4                       Natural Gas  2025-01-20 02:59:02.737000-08:00
# ...                             ...                               ...
# 6160                      Rice Husk  2025-07-15 01:38:17.376000-07:00
# 6161                            HSD  2025-09-01 23:40:19.098000-07:00
# 6162                           Coal  2025-09-01 23:41:02.578000-07:00
# 6163  Natural Gas (Reformer Burner)  2025-09-22 23:49:02.407000-07:00
# 6164   Natural Gas (Boiler+HRSG+GT)  2025-09-22 23:50:08.849000-07:00
#
#            ch4       n2o           ef           co2
# 0     0.000000  0.000000    93.864500      0.000000
# 1     0.000001  0.000000    53.114500      0.000054
# 2     0.000001  0.000000    53.114500      0.000054
# 3     0.000076  0.000008    53.114500      0.004029
# 4     0.000203  0.000020    53.114500      0.010779
# ...        ...       ...          ...           ...
# 6160  0.214951  0.013614     0.031000      0.000000
# 6161  0.000003  0.000001  2697.910000      0.053635
# 6162  0.537400  0.161220  1683.950000   9002.524800
# 6163  0.482067  0.024103     2.170000  12051.670330
# 6164  0.261096  0.013055     2.170000   6527.405889
#
# [6165 rows x 8 columns]

# %% [markdown]
# ## Data Cleaning
#
# We will first create hour, day of week, and month-based variables to account for factors like seasonality.

# %%
# Convert 'createdAt' to datetime objects
df['createdAt'] = pd.to_datetime(df['createdAt'], utc=True)

# --- 2. Feature Engineering ---

# Extract time-based features
df['hour'] = df['createdAt'].dt.hour
df['day_of_week'] = df['createdAt'].dt.dayofweek # Monday=0, Sunday=6
df['is_weekend'] = df['day_of_week'].apply(lambda x: 1 if x >= 5 else 0)
df['month'] = df['createdAt'].dt.month

# For cyclical seasonality, convert month to sine and cosine features
df['month_sin'] = np.sin(2 * np.pi * df['month']/12)
df['month_cos'] = np.cos(2 * np.pi * df['month']/12)

# %% [markdown]
# This section of code factors in a manual "event log" that can account for changes in production, such as a facility being inactive during a certain period of time, or producing higher rates of a product during a certain busy time, and factoring that into the emission readings accordingly.

# %%
# --- 6. Event Log Integration and Feature Creation ---

# 1. Simulate the Event Log (This is where the user/system input goes)
# Example: Facility X increases production by 50% from June 1st to July 31st
event_log = pd.read_csv("empty_event_log.csv")

# 2. Initialize the new feature to the baseline (1.0, meaning no change)
df['production_boost_factor'] = 1.0

# 3. Apply the boost factor for records that fall within event periods
for _, event in event_log.iterrows():
    # Check if a record is from the facility AND within the event's date range
    mask = (df['facilityId'] == event['facilityId']) & \
           (df['createdAt'] >= event['event_start']) & \
           (df['createdAt'] <= event['event_end'])
    
    # Apply the magnitude to the new feature column
    df.loc[mask, 'production_boost_factor'] = event['magnitude']

print(f"Applied production boost to {df[df['production_boost_factor'] > 1.0].shape[0]} records.")
# Out:
# Applied production boost to 0 records.

# %% [markdown]
# We keep the necessary features in our data and prepare the data for our model.

# %%
# Define the features to be used in the model
NUMERICAL_FEATURES = ['co2e', 'ch4', 'n2o', 'ef', 'co2', 'month_sin', 'month_cos', 'production_boost_factor']
TIME_FEATURES = ['hour', 'day_of_week', 'is_weekend']
CATEGORICAL_FEATURES = ['facilityId', 'fuelHint']

FEATURES = NUMERICAL_FEATURES + TIME_FEATURES + CATEGORICAL_FEATURES
X = df[FEATURES]

# --- 3. Preprocessing Pipeline ---

# Create transformers for different feature types
numerical_transformer = StandardScaler() # Scaling is crucial for Isolation Forest

# One-Hot Encoding for categorical features
categorical_transformer = OneHotEncoder(handle_unknown='ignore', sparse_output=False)

# Combine transformers using ColumnTransformer
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, NUMERICAL_FEATURES + TIME_FEATURES),
        ('cat', categorical_transformer, CATEGORICAL_FEATURES)
    ],
    remainder='drop' # Drop other columns not specified
)

# %% [markdown]
# ## Model Creation
#
# This section is where we define and create our model. We train it to prioritize recent data (such as in the last six months) and fit our data to the model.

# %%
# The Isolation Forest model is typically trained on all data since we don't have labeled anomalies.
# 'contamination' is the expected proportion of anomalies in the dataset (e.g., 1%).
# Setting a reasonable contamination value helps the model set its internal threshold.

# Define the model within a pipeline for clean preprocessing and fitting
anomaly_detector = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('model', IsolationForest(
        n_estimators=100,
        contamination='auto',
        random_state=42,
        n_jobs=-1 # Use all available cores
    ))
])

# --- 5. Training and Prediction ---

print("Training Isolation Forest model...")

# # Assuming 'df' is your historical data and you want to use the last 6 months
# six_months_ago = pd.to_datetime('today', utc=True) - pd.DateOffset(months=6)

# # Filter the data for the rolling window
# recent_data = df[df['createdAt'] >= six_months_ago]
# X_recent = recent_data[FEATURES]

anomaly_detector.fit(X)

# Get the anomaly scores (lower score means more anomalous)
# Note: Isolation Forest outputs a score where higher is 'normal'.
# We often use .decision_function() for the raw score.
df['anomaly_score'] = anomaly_detector.decision_function(X)

# Predict the anomaly classification (-1 for anomaly, 1 for normal) using a rolling window

# --- 1. Prepare Data for Rolling Calculation ---
# The rolling calculation requires the data to be sorted by time (which is usually the case
# but we ensure it) and ideally, set the time column as the index.
df = df.sort_values('createdAt').set_index('createdAt')

# --- 2. Define Parameters ---
# The size of the window to look back and calculate the 'normal' distribution.
WINDOW_SIZE = '180D'
# The contamination rate (e.g., 1st percentile) to set the threshold.
CONTAMINATION_RATE = 0.01

# --- 3. Calculate the Rolling Dynamic Threshold ---
# Calculate the threshold (1st percentile) for the anomaly scores 
# based on the preceding 30 days of data.
# 'closed='left'' ensures the threshold for time 't' is calculated using data from 
# (t - 30 days) up to (t), but EXCLUDING the observation at time 't' itself.
# This prevents the current point from influencing its own threshold.

df['rolling_threshold'] = (
    df['anomaly_score']
      .rolling(window=WINDOW_SIZE, closed='left')
      .quantile(CONTAMINATION_RATE)
)

# --- 4. Handle Cold-Start Period ---
# The first 30 days will have 'NaN' for the rolling_threshold. 
# We can use the overall static threshold (from the IF model) for this initial period.
# The Isolation Forest model's internal threshold is the 1% quantile of the full training set scores.
# We calculate this static fallback threshold once.
static_fallback_threshold = df['anomaly_score'].quantile(CONTAMINATION_RATE)
df['rolling_threshold'] = df['rolling_threshold'].fillna(static_fallback_threshold)

# --- 5. Apply the Rolling Dynamic Threshold ---
# Points are anomalies (-1) if their score is LESS THAN the rolling threshold
df['anomaly_label_dynamic_rolling'] = np.where(
    df['anomaly_score'] < df['rolling_threshold'], 
    -1, 
    1
)

# Reset index to original state if needed for downstream operations
df = df.reset_index()

print("Training complete.")
# Out:
# Training Isolation Forest model...
# Training complete.

# %% [markdown]
# ## Results

# %%
# --- Display Results ---

print("\nSample of Dynamic Threshold and Labeling:")
print(df[['createdAt', 'anomaly_score', 'rolling_threshold', 'anomaly_label_dynamic_rolling']].tail(5))

anomalies = df[df['anomaly_label_dynamic_rolling'] == -1].sort_values(by='anomaly_score')

print(f"\nTotal Anomalies Detected [Rolling Dynamic]: {df['anomaly_label_dynamic_rolling'].value_counts().get(-1, 0)}")

print(anomalies[['createdAt','facilityId','fuelHint', 'co2e', 'anomaly_score']])
# Out:
# Sample of Dynamic Threshold and Labeling:
#                             createdAt  anomaly_score  rolling_threshold  \
# 6160 2025-09-23 06:49:02.407000+00:00       0.122298           0.139256
# 6161 2025-09-23 06:49:02.407000+00:00       0.122298           0.139256
# 6162 2025-09-23 06:50:08.849000+00:00       0.138808           0.138201
# 6163 2025-09-23 06:50:08.849000+00:00       0.138808           0.138201
# 6164 2025-09-23 06:50:08.849000+00:00       0.138808           0.138201
#
#       anomaly_label_dynamic_rolling
# 6160                             -1
# 6161                             -1
# 6162                              1
# 6163                              1
# 6164                              1
#
# Total Anomalies Detected [Rolling Dynamic]: 246
#                             createdAt                            facilityId  \
# 5198 2025-03-20 03:56:15.627000+00:00  beae4852-c882-4706-8dd9-f8ce4dc11989
# 5196 2025-03-20 03:56:15.627000+00:00  beae4852-c882-4706-8dd9-f8ce4dc11989
# 5197 2025-03-20 03:56:15.627000+00:00  beae4852-c882-4706-8dd9-f8ce4dc11989
# 6145 2025-07-10 09:22:48.624000+00:00  ffcd9d3d-c381-4e6b-9f20-393bc616132a
# 6146 2025-07-10 09:22:48.624000+00:00  ffcd9d3d-c381-4e6b-9f20-393bc616132a
# ...                               ...                                   ...
# 1324 2025-01-20 11:03:10.121000+00:00  2f79e7cf-97ef-496b-9c55-04ff2f0d33ba
# 1323 2025-01-20 11:03:10.121000+00:00  2f79e7cf-97ef-496b-9c55-04ff2f0d33ba
# 7    2025-01-20 10:59:01.888000+00:00  4f4bf05a-0a52-48db-b66d-3b3da6b23619
# 6    2025-01-20 10:59:01.888000+00:00  4f4bf05a-0a52-48db-b66d-3b3da6b23619
# 8    2025-01-20 10:59:01.888000+00:00  4f4bf05a-0a52-48db-b66d-3b3da6b23619
#
#          fuelHint            co2e  anomaly_score
# 5198         Coal  3357926.348112       0.096178
# 5196         Coal  3357926.348112       0.096178
# 5197         Coal  3357926.348112       0.096178
# 6145         Coal   170737.098157       0.116902
# 6146         Coal   170737.098157       0.116902
# ...           ...             ...            ...
# 1324  Natural Gas        0.008229       0.178948
# 1323  Natural Gas        0.008229       0.178948
# 7     Natural Gas        0.000054       0.181234
# 6     Natural Gas        0.000054       0.181234
# 8     Natural Gas        0.000054       0.181234
#
# [246 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Pick a facility to visualize (e.g., the one with the most records)
target_facility = df['facilityId'].value_counts().idxmax()
plot_data = df[df['facilityId'] == target_facility]

plt.figure(figsize=(15, 7))

# 1. Plot the continuous Anomaly Score
sns.lineplot(data=plot_data, x=plot_data.index, y='anomaly_score', 
             label='Isolation Forest Score', color='#1f77b4', alpha=0.5)

# 2. Plot the Dynamic Threshold line
plt.step(plot_data.index, plot_data['rolling_threshold'], where='post', 
         label=f'Dynamic Threshold ({WINDOW_SIZE})', color='#ff7f0e', linestyle='--', linewidth=2)

# 3. Highlight the Anomalies in Red
anomalies = plot_data[plot_data['anomaly_label_dynamic_rolling'] == -1]
plt.scatter(anomalies.index, anomalies['anomaly_score'], 
            color='red', label='Detected Anomaly', zorder=5, s=50)

# Formatting
plt.title(f'Anomaly Detection Analysis: Facility {target_facility}', fontsize=16)
plt.suptitle(f'Threshold adapted based on rolling {WINDOW_SIZE} window', fontsize=10, y=0.92)
plt.xlabel('Time', fontsize=12)
plt.ylabel('Score (Lower = More Anomalous)', fontsize=12)
plt.legend(loc='upper right')
plt.grid(True, which='both', linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()
